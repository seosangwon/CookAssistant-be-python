# %%
from langserve import RemoteRunnable

chain = RemoteRunnable(
    chain = RemoteRunnable("http://localhost:8100/create-recipe/c/N4XyA")
)

for token in chain.stream(
    {"task": "락토오보 베지터리언도 먹을 수 있는 카레 레시피 알려줘"}
):
    print(token, end="")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/seosang-won/study/langserve-template/example/01-remote-invoke.ipynb 셀 1 line 3
#       <a href='vscode-notebook-cell:/Users/seosang-won/study/langserve-template/example/01-remote-invoke.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> from langserve import RemoteRunnable
# ----> <a href='vscode-notebook-cell:/Users/seosang-won/study/langserve-template/example/01-remote-invoke.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> chain = RemoteRunnable(
#       <a href='vscode-notebook-cell:/Users/seosang-won/study/langserve-template/example/01-remote-invoke.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a>     chain = RemoteRunnable("http://localhost:8100/create-recipe/c/N4XyA")
#       <a href='vscode-notebook-cell:/Users/seosang-won/study/langserve-template/example/01-remote-invoke.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> )
#       <a href='vscode-notebook-cell:/Users/seosang-won/study/langserve-template/example/01-remote-invoke.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a> for token in chain.stream(
#       <a href='vscode-notebook-cell:/Users/seosang-won/study/langserve-template/example/01-remote-invoke.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a>     {"task": "락토오보 베지터리언도 먹을 수 있는 카레 레시피 알려줘"}
#       <a href='vscode-notebook-cell:/Users/seosang-won/study/langserve-template/example/01-remote-invoke.ipynb#W0sZmlsZQ%3D%3D?line=8'>9</a> ):
#      <a href='vscode-notebook-cell:/Users/seosang-won/study/langserve-template/example/01-remote-invoke.ipynb#W0sZmlsZQ%3D%3D?line=9'>10</a>     print(token, end="")
#
# TypeError: RemoteRunnable.__init__() got an unexpected keyword argument 'chain'

# %%
from langserve import RemoteRunnable

chain = RemoteRunnable("http://localhost:8100/create-recipe/c/N4XyA")
chain.invoke({ ... })
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/callbacks/manager.py", line 1997, in _configure
#     handler = LangChainTracer(project_name=tracer_project)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/tracers/langchain.py", line 91, in __init__
#     self.client = client or get_client()
#                             ^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/tracers/langchain.py", line 54, in get_client
#     _CLIENT = Client()
#               ^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/langsmith/client.py", line 534, in __init__
#     _validate_api_key_if_hosted(self.api_url, self.api_key)
#   File "/opt/homebrew/lib/python3.11/site-packages/langsmith/client.py", line 323, in _validate_api_key_if_hosted
#     raise ls_utils.LangSmithUserError(
# langsmith.utils.LangSmithUserError: API key must be provided when using hosted LangSmith API
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py", line 687, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py", line 377, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/seosang-won/Library/Python/3.11/lib/python/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/seosang-won/Library/Python/3.11/lib/python/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/seosang-won/Library/Python/3.11/lib/python/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/opt/homebrew/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/seosang-won/Library/Python/3.11/lib/python/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/Users/seosang-won/Library/Python/3.11/lib/python/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/Users/seosang-won/Library/Python/3.11/lib/python/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/Users/seosang-won/Library/Python/3.11/lib/python/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/seosang-won/Library/Python/3.11/lib/python/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/Users/seosang-won/Library/Python/3.11/lib/python/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/Users/seosang-won/Library/Python/3.11/lib/python/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/seosang-won/Library/Python/3.11/lib/python/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/Users/seosang-won/Library/Python/3.11/lib/python/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/Users/seosang-won/Library/Python/3.11/lib/python/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/seosang-won/Library/Python/3.11/lib/python/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/seosang-won/Library/Python/3.11/lib/python/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/seosang-won/Library/Python/3.11/lib/python/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/fw/7scvhfyd5wb2pqbgkrq_09g40000gn/T/ipykernel_79754/425305859.py", line 13, in <module>
#     runnable.invoke({"num": 1})
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/runnables/base.py", line 3110, in invoke
#     callback_manager = CallbackManager.configure(
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/callbacks/manager.py", line 1449, in configure
#     return _configure(
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/callbacks/manager.py", line 2000, in _configure
#     logger.warning(
# Message: 'Unable to load requested LangChainTracer. To disable this warning, unset the LANGCHAIN_TRACING_V2 environment variables.'
# Arguments: (LangSmithUserError('API key must be provided when using hosted LangSmith API'),)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/callbacks/manager.py", line 1997, in _configure
#     handler = LangChainTracer(project_name=tracer_project)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/tracers/langchain.py", line 91, in __init__
#     self.client = client or get_client()
#                             ^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/tracers/langchain.py", line 54, in get_client
#     _CLIENT = Client()
#               ^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/langsmith/client.py", line 534, in __init__
#     _validate_api_key_if_hosted(self.api_url, self.api_key)
#   File "/opt/homebrew/lib/python3.11/site-packages/langsmith/client.py", line 323, in _validate_api_key_if_hosted
#     raise ls_utils.LangSmithUserError(
# langsmith.utils.LangSmithUserError: API key must be provided when using hosted LangSmith API
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py", line 687, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py", line 377, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Users/seosang-won/Library/Python/3.11/lib/python/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/runnables/passthrough.py", line 218, in invoke
#     return self._call_with_config(identity, input, config)
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/runnables/base.py", line 1611, in _call_with_config
#     callback_manager = get_callback_manager_for_config(config)
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/runnables/config.py", line 402, in get_callback_manager_for_config
#     return CallbackManager.configure(
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/callbacks/manager.py", line 1449, in configure
#     return _configure(
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/callbacks/manager.py", line 2000, in _configure
#     logger.warning(
# Message: 'Unable to load requested LangChainTracer. To disable this warning, unset the LANGCHAIN_TRACING_V2 environment variables.'
# Arguments: (LangSmithUserError('API key must be provided when using hosted LangSmith API'),)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/callbacks/manager.py", line 1997, in _configure
#     handler = LangChainTracer(project_name=tracer_project)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/tracers/langchain.py", line 91, in __init__
#     self.client = client or get_client()
#                             ^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/tracers/langchain.py", line 54, in get_client
#     _CLIENT = Client()
#               ^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/langsmith/client.py", line 534, in __init__
#     _validate_api_key_if_hosted(self.api_url, self.api_key)
#   File "/opt/homebrew/lib/python3.11/site-packages/langsmith/client.py", line 323, in _validate_api_key_if_hosted
#     raise ls_utils.LangSmithUserError(
# langsmith.utils.LangSmithUserError: API key must be provided when using hosted LangSmith API
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py", line 687, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py", line 377, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Users/seosang-won/Library/Python/3.11/lib/python/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/runnables/passthrough.py", line 455, in invoke
#     return self._call_with_config(self._invoke, input, config, **kwargs)
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/runnables/base.py", line 1611, in _call_with_config
#     callback_manager = get_callback_manager_for_config(config)
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/runnables/config.py", line 402, in get_callback_manager_for_config
#     return CallbackManager.configure(
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/callbacks/manager.py", line 1449, in configure
#     return _configure(
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/callbacks/manager.py", line 2000, in _configure
#     logger.warning(
# Message: 'Unable to load requested LangChainTracer. To disable this warning, unset the LANGCHAIN_TRACING_V2 environment variables.'
# Arguments: (LangSmithUserError('API key must be provided when using hosted LangSmith API'),)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/callbacks/manager.py", line 1997, in _configure
#     handler = LangChainTracer(project_name=tracer_project)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/tracers/langchain.py", line 91, in __init__
#     self.client = client or get_client()
#                             ^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/tracers/langchain.py", line 54, in get_client
#     _CLIENT = Client()
#               ^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/langsmith/client.py", line 534, in __init__
#     _validate_api_key_if_hosted(self.api_url, self.api_key)
#   File "/opt/homebrew/lib/python3.11/site-packages/langsmith/client.py", line 323, in _validate_api_key_if_hosted
#     raise ls_utils.LangSmithUserError(
# langsmith.utils.LangSmithUserError: API key must be provided when using hosted LangSmith API
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py", line 687, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py", line 377, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Users/seosang-won/Library/Python/3.11/lib/python/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/runnables/base.py", line 3967, in invoke
#     return self._call_with_config(
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/runnables/base.py", line 1611, in _call_with_config
#     callback_manager = get_callback_manager_for_config(config)
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/runnables/config.py", line 402, in get_callback_manager_for_config
#     return CallbackManager.configure(
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/callbacks/manager.py", line 1449, in configure
#     return _configure(
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/callbacks/manager.py", line 2000, in _configure
#     logger.warning(
# Message: 'Unable to load requested LangChainTracer. To disable this warning, unset the LANGCHAIN_TRACING_V2 environment variables.'
# Arguments: (LangSmithUserError('API key must be provided when using hosted LangSmith API'),)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/callbacks/manager.py", line 1997, in _configure
#     handler = LangChainTracer(project_name=tracer_project)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/tracers/langchain.py", line 91, in __init__
#     self.client = client or get_client()
#                             ^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/tracers/langchain.py", line 54, in get_client
#     _CLIENT = Client()
#               ^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/langsmith/client.py", line 534, in __init__
#     _validate_api_key_if_hosted(self.api_url, self.api_key)
#   File "/opt/homebrew/lib/python3.11/site-packages/langsmith/client.py", line 323, in _validate_api_key_if_hosted
#     raise ls_utils.LangSmithUserError(
# langsmith.utils.LangSmithUserError: API key must be provided when using hosted LangSmith API
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py", line 687, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py", line 377, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Users/seosang-won/Library/Python/3.11/lib/python/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/runnables/passthrough.py", line 455, in invoke
#     return self._call_with_config(self._invoke, input, config, **kwargs)
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/runnables/base.py", line 1625, in _call_with_config
#     context.run(
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/runnables/config.py", line 347, in call_func_with_variable_args
#     return func(input, **kwargs)  # type: ignore[call-arg]
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/runnables/passthrough.py", line 442, in _invoke
#     **self.mapper.invoke(
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/runnables/base.py", line 3110, in invoke
#     callback_manager = CallbackManager.configure(
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/callbacks/manager.py", line 1449, in configure
#     return _configure(
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/callbacks/manager.py", line 2000, in _configure
#     logger.warning(
# Message: 'Unable to load requested LangChainTracer. To disable this warning, unset the LANGCHAIN_TRACING_V2 environment variables.'
# Arguments: (LangSmithUserError('API key must be provided when using hosted LangSmith API'),)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/callbacks/manager.py", line 1997, in _configure
#     handler = LangChainTracer(project_name=tracer_project)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/tracers/langchain.py", line 91, in __init__
#     self.client = client or get_client()
#                             ^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/tracers/langchain.py", line 54, in get_client
#     _CLIENT = Client()
#               ^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/langsmith/client.py", line 534, in __init__
#     _validate_api_key_if_hosted(self.api_url, self.api_key)
#   File "/opt/homebrew/lib/python3.11/site-packages/langsmith/client.py", line 323, in _validate_api_key_if_hosted
#     raise ls_utils.LangSmithUserError(
# langsmith.utils.LangSmithUserError: API key must be provided when using hosted LangSmith API
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py", line 687, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/logging/__init__.py", line 377, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Users/seosang-won/Library/Python/3.11/lib/python/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/runnables/base.py", line 3967, in invoke
#     return self._call_with_config(
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/runnables/base.py", line 1611, in _call_with_config
#     callback_manager = get_callback_manager_for_config(config)
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/runnables/config.py", line 402, in get_callback_manager_for_config
#     return CallbackManager.configure(
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/callbacks/manager.py", line 1449, in configure
#     return _configure(
#   File "/opt/homebrew/lib/python3.11/site-packages/langchain_core/callbacks/manager.py", line 2000, in _configure
#     logger.warning(
# Message: 'Unable to load requested LangChainTracer. To disable this warning, unset the LANGCHAIN_TRACING_V2 environment variables.'
# Arguments: (LangSmithUserError('API key must be provided when using hosted LangSmith API'),)
# {'passed': {'num': 1}, 'extra': {'num': 1, 'mult': 3}, 'modified': 2}
